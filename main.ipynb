# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
df = pd.read_csv("flight_data_1000.csv")
df
# Out:
#         FL_DATE  DEP_DELAY ORIGIN_CITY_NAME DEST_CITY_NAME  CRS_DEP_TIME  \
# 0    2024-08-16         -3          Houston  San Francisco          1167
# 1    2024-08-08         10          Houston       New York           941
# 2    2024-08-06         59    San Francisco        Houston           829
# 3    2024-08-12         14          Atlanta        Atlanta          1770
# 4    2024-08-24          1          Atlanta        Chicago           975
# ..          ...        ...              ...            ...           ...
# 995  2024-08-17         16          Atlanta        Seattle          1380
# 996  2024-08-15         55            Miami        Atlanta          1565
# 997  2024-08-12         30    San Francisco       New York          2080
# 998  2024-08-30          2          Seattle        Houston          1993
# 999  2024-08-16         -2      Los Angeles        Houston          1547
#
#      DISTANCE
# 0        1161
# 1         454
# 2        1204
# 3        1569
# 4         704
# ..        ...
# 995      2147
# 996       506
# 997      2498
# 998       464
# 999      2298
#
# [1000 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['FL_DATE', 'DEP_DELAY', 'ORIGIN_CITY_NAME', 'DEST_CITY_NAME',
#        'CRS_DEP_TIME', 'DISTANCE'],
#       dtype='object')

# %%
df['FL_DATE'] = pd.to_datetime(df['FL_DATE'])
df.set_index('FL_DATE', inplace=True)

# %%
features = df.columns[0:]
df = df[features].dropna()
df
# Out:
#             DEP_DELAY ORIGIN_CITY_NAME DEST_CITY_NAME  CRS_DEP_TIME  DISTANCE
# FL_DATE
# 2024-08-16         -3          Houston  San Francisco          1167      1161
# 2024-08-08         10          Houston       New York           941       454
# 2024-08-06         59    San Francisco        Houston           829      1204
# 2024-08-12         14          Atlanta        Atlanta          1770      1569
# 2024-08-24          1          Atlanta        Chicago           975       704
# ...               ...              ...            ...           ...       ...
# 2024-08-17         16          Atlanta        Seattle          1380      2147
# 2024-08-15         55            Miami        Atlanta          1565       506
# 2024-08-12         30    San Francisco       New York          2080      2498
# 2024-08-30          2          Seattle        Houston          1993       464
# 2024-08-16         -2      Los Angeles        Houston          1547      2298
#
# [1000 rows x 5 columns]

# %%
df = pd.get_dummies(df, columns=['ORIGIN_CITY_NAME', 'DEST_CITY_NAME'])
df
# Out:
#             DEP_DELAY  CRS_DEP_TIME  DISTANCE  ORIGIN_CITY_NAME_Atlanta  \
# FL_DATE
# 2024-08-16         -3          1167      1161                     False
# 2024-08-08         10           941       454                     False
# 2024-08-06         59           829      1204                     False
# 2024-08-12         14          1770      1569                      True
# 2024-08-24          1           975       704                      True
# ...               ...           ...       ...                       ...
# 2024-08-17         16          1380      2147                      True
# 2024-08-15         55          1565       506                     False
# 2024-08-12         30          2080      2498                     False
# 2024-08-30          2          1993       464                     False
# 2024-08-16         -2          1547      2298                     False
#
#             ORIGIN_CITY_NAME_Chicago  ORIGIN_CITY_NAME_Dallas  \
# FL_DATE
# 2024-08-16                     False                    False
# 2024-08-08                     False                    False
# 2024-08-06                     False                    False
# 2024-08-12                     False                    False
# 2024-08-24                     False                    False
# ...                              ...                      ...
# 2024-08-17                     False                    False
# 2024-08-15                     False                    False
# 2024-08-12                     False                    False
# 2024-08-30                     False                    False
# 2024-08-16                     False                    False
#
#             ORIGIN_CITY_NAME_Denver  ORIGIN_CITY_NAME_Houston  \
# FL_DATE
# 2024-08-16                    False                      True
# 2024-08-08                    False                      True
# 2024-08-06                    False                     False
# 2024-08-12                    False                     False
# 2024-08-24                    False                     False
# ...                             ...                       ...
# 2024-08-17                    False                     False
# 2024-08-15                    False                     False
# 2024-08-12                    False                     False
# 2024-08-30                    False                     False
# 2024-08-16                    False                     False
#
#             ORIGIN_CITY_NAME_Los Angeles  ORIGIN_CITY_NAME_Miami  ...  \
# FL_DATE                                                           ...
# 2024-08-16                         False                   False  ...
# 2024-08-08                         False                   False  ...
# 2024-08-06                         False                   False  ...
# 2024-08-12                         False                   False  ...
# 2024-08-24                         False                   False  ...
# ...                                  ...                     ...  ...
# 2024-08-17                         False                   False  ...
# 2024-08-15                         False                    True  ...
# 2024-08-12                         False                   False  ...
# 2024-08-30                         False                   False  ...
# 2024-08-16                          True                   False  ...
#
#             DEST_CITY_NAME_Atlanta  DEST_CITY_NAME_Chicago  \
# FL_DATE
# 2024-08-16                   False                   False
# 2024-08-08                   False                   False
# 2024-08-06                   False                   False
# 2024-08-12                    True                   False
# 2024-08-24                   False                    True
# ...                            ...                     ...
# 2024-08-17                   False                   False
# 2024-08-15                    True                   False
# 2024-08-12                   False                   False
# 2024-08-30                   False                   False
# 2024-08-16                   False                   False
#
#             DEST_CITY_NAME_Dallas  DEST_CITY_NAME_Denver  \
# FL_DATE
# 2024-08-16                  False                  False
# 2024-08-08                  False                  False
# 2024-08-06                  False                  False
# 2024-08-12                  False                  False
# 2024-08-24                  False                  False
# ...                           ...                    ...
# 2024-08-17                  False                  False
# 2024-08-15                  False                  False
# 2024-08-12                  False                  False
# 2024-08-30                  False                  False
# 2024-08-16                  False                  False
#
#             DEST_CITY_NAME_Houston  DEST_CITY_NAME_Los Angeles  \
# FL_DATE
# 2024-08-16                   False                       False
# 2024-08-08                   False                       False
# 2024-08-06                    True                       False
# 2024-08-12                   False                       False
# 2024-08-24                   False                       False
# ...                            ...                         ...
# 2024-08-17                   False                       False
# 2024-08-15                   False                       False
# 2024-08-12                   False                       False
# 2024-08-30                    True                       False
# 2024-08-16                    True                       False
#
#             DEST_CITY_NAME_Miami  DEST_CITY_NAME_New York  \
# FL_DATE
# 2024-08-16                 False                    False
# 2024-08-08                 False                     True
# 2024-08-06                 False                    False
# 2024-08-12                 False                    False
# 2024-08-24                 False                    False
# ...                          ...                      ...
# 2024-08-17                 False                    False
# 2024-08-15                 False                    False
# 2024-08-12                 False                     True
# 2024-08-30                 False                    False
# 2024-08-16                 False                    False
#
#             DEST_CITY_NAME_San Francisco  DEST_CITY_NAME_Seattle
# FL_DATE
# 2024-08-16                          True                   False
# 2024-08-08                         False                   False
# 2024-08-06                         False                   False
# 2024-08-12                         False                   False
# 2024-08-24                         False                   False
# ...                                  ...                     ...
# 2024-08-17                         False                    True
# 2024-08-15                         False                   False
# 2024-08-12                         False                   False
# 2024-08-30                         False                   False
# 2024-08-16                         False                   False
#
# [1000 rows x 23 columns]

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)
scaled_data
# Out:
# array([[0.10144928, 0.48558295, 0.39144288, ..., 0.        , 1.        ,
#         0.        ],
#        [0.28985507, 0.39114083, 0.06964042, ..., 1.        , 0.        ,
#         0.        ],
#        [1.        , 0.34433765, 0.41101502, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.57971014, 0.86711241, 1.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.17391304, 0.83075637, 0.07419208, ..., 0.        , 0.        ,
#         0.        ],
#        [0.11594203, 0.64437944, 0.90896677, ..., 0.        , 0.        ,
#         0.        ]])

# %%
def create_sequences(data, seq_length):
    sequences = []
    for i in range(len(data) - seq_length):
        seq = data[i:i+seq_length]
        target = data[i + seq_length][0]
        sequences.append((seq, target))
    return sequences

seq_length = 30
sequences = create_sequences(scaled_data, seq_length)
len(sequences)
# Out:
# 970

# %%
train_size = int(len(sequences) * 0.8)
train_sequences = sequences[:train_size]
test_sequences = sequences[train_size:]

X_train, y_train = zip(*train_sequences)
X_train, y_train = np.array(X_train), np.array(y_train)

X_test, y_test = zip(*test_sequences)
X_test, y_test = np.array(X_test), np.array(y_test)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (776, 30, 23) (194, 30, 23) (776,) (194,)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(seq_length, X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(50))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /Users/raifsalauddinmondal/Documents/GitHub/Flight-Prediction/env/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.1533 - val_loss: 0.0858
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0928 - val_loss: 0.0843
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0901 - val_loss: 0.0869
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0856 - val_loss: 0.0827
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0863 - val_loss: 0.0834
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0861 - val_loss: 0.0847
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0917 - val_loss: 0.0855
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0836 - val_loss: 0.0877
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0856 - val_loss: 0.0840
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0797 - val_loss: 0.0838
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0799 - val_loss: 0.0862
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0783 - val_loss: 0.0860
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0826 - val_loss: 0.0858
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0892 - val_loss: 0.0889
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0822 - val_loss: 0.0876
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0817 - val_loss: 0.0853
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0812 - val_loss: 0.0905
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0766 - val_loss: 0.0886
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0834 - val_loss: 0.0894
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0830 - val_loss: 0.0890
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0740 - val_loss: 0.0923
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0810 - val_loss: 0.0915
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0778 - val_loss: 0.1185
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0819 - val_loss: 0.1038
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0779 - val_loss: 0.0926
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0764 - val_loss: 0.1008
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0713 - val_loss: 0.0990
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0726 - val_loss: 0.1079
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0748 - val_loss: 0.0930
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0762 - val_loss: 0.0999
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0685 - val_loss: 0.1066
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0715 - val_loss: 0.1076
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0694 - val_loss: 0.1081
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0696 - val_loss: 0.1111
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0680 - val_loss: 0.1095
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0710 - val_loss: 0.1106
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0687 - val_loss: 0.1183
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0695 - val_loss: 0.1113
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0709 - val_loss: 0.1083
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0689 - val_loss: 0.1070
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0677 - val_loss: 0.1157
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0654 - val_loss: 0.1190
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0661 - val_loss: 0.1259
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0672 - val_loss: 0.1171
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0664 - val_loss: 0.1282
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0674 - val_loss: 0.1289
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0654 - val_loss: 0.1284
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0620 - val_loss: 0.1315
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0628 - val_loss: 0.1243
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0666 - val_loss: 0.1231

# %%
preds = model.predict(X_test)
preds = scaler.inverse_transform(np.concatenate((preds, np.zeros((preds.shape[0], scaled_data.shape[1] - 1))), axis=1))[:0]
from sklearn.preprocessing import MinMaxScaler

ft_data = {
    'DEP_DELAY': 0,
    'ORIGIN_CITY_NAME': 'Houston',
    'DEST_CITY_NAME': "New York",
    'CRS_DEP_TIME': 1230,
    'DISTANCE': 454
}
ft_df = pd.DataFrame([ft_data])
ft_df = pd.get_dummies(ft_df, columns=['ORIGIN_CITY_NAME', 'DEST_CITY_NAME'])
scaler_columns = list(scaler.feature_names_in_)

for col in scaler_columns:
    if col not in ft_df.columns:
        ft_df[col] = 0

ft_df = ft_df[scaler_columns]
scaled_future_flight = scaler.transform(ft_df)
seq_length = 30

future_sequence = np.array([scaled_future_flight] * seq_length)
future_sequence = future_sequence.reshape(1, seq_length, future_sequence.shape[2])
predicted_delay = model.predict(future_sequence)
predicted_delay = scaler.inverse_transform(
    np.concatenate(
        (predicted_delay, np.zeros((predicted_delay.shape[0], scaled_future_flight.shape[1] - 1))),
        axis=1
    )
)[:, 0]
print(f"Predicted delay for the specific future flight: {predicted_delay[0]:.2f} minutes")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted delay for the specific future flight: 26.52 minutes
